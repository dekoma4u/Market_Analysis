# %%
#!pip install plotly

# %%
import pandas as pd
import plotly
pd.options.plotting.backend = "plotly"
import matplotlib.pyplot as plt

# %%
#!pip install openpyxl

# %%
old_df = pd.read_excel("Online Retail.xlsx")
old_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
old_df.duplicated().sum()
# Out:
# 5268

# %%
df = old_df.drop_duplicates()

# %%
df.Country.value_counts()
# Out:
# United Kingdom          490300
# Germany                   9480
# France                    8541
# EIRE                      8184
# Spain                     2528
# Netherlands               2371
# Belgium                   2069
# Switzerland               1994
# Portugal                  1510
# Australia                 1258
# Norway                    1086
# Italy                      803
# Channel Islands            757
# Finland                    695
# Cyprus                     611
# Sweden                     461
# Unspecified                442
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     294
# USA                        291
# Hong Kong                  284
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
max_unitPrice = df.sort_values(by=['UnitPrice'], ascending=False)
max_unitPrice
# Out:
#        InvoiceNo  StockCode                   Description  Quantity  \
# 222681   C556445          M                        Manual        -1
# 524602   C580605  AMAZONFEE                    AMAZON FEE        -1
# 43702    C540117  AMAZONFEE                    AMAZON FEE        -1
# 43703    C540118  AMAZONFEE                    AMAZON FEE        -1
# 15016    C537630  AMAZONFEE                    AMAZON FEE        -1
# ...          ...        ...                           ...       ...
# 193208    553521      22520    CHILDS GARDEN TROWEL BLUE          1
# 193207    553521      22524  CHILDRENS GARDEN GLOVES BLUE         1
# 116919    546307     84029G                           NaN       280
# 299984   A563187          B               Adjust bad debt         1
# 299983   A563186          B               Adjust bad debt         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 222681 2011-06-10 15:31:00   38970.00     15098.0  United Kingdom
# ...

# %%
max_quant = df.sort_values(by=['Quantity'], ascending=False)
max_quant
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
# 74614     542504     37413                                  NaN      5568
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# ...          ...       ...                                  ...       ...
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 225529    556690     23005         printing smudges/thrown away     -9600
# 225530    556691     23005         printing smudges/thrown away     -9600
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
country_mostsold = df.Country.value_counts()
country_mostsold
# Out:
# United Kingdom          490300
# Germany                   9480
# France                    8541
# EIRE                      8184
# Spain                     2528
# Netherlands               2371
# Belgium                   2069
# Switzerland               1994
# Portugal                  1510
# Australia                 1258
# Norway                    1086
# Italy                      803
# Channel Islands            757
# Finland                    695
# Cyprus                     611
# Sweden                     461
# Unspecified                442
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     294
# USA                        291
# Hong Kong                  284
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
country_group = df.groupby("Country", group_keys=True).apply(lambda x: x)
country_group
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
grouping = df.groupby(df.Country).sum()
data_view = grouping.sort_values(by="Quantity", ascending=False)
data_view = data_view.drop(columns=["CustomerID"])
data_view
# Out:
#                       Quantity    UnitPrice
# Country
# United Kingdom         4250328  2233247.604
# Netherlands             200128     6492.550
# EIRE                    142495    48400.370
# Germany                 117341    37633.440
# France                  110438    42985.980
# Australia                83643     4048.000
# Sweden                   35632     1804.730
# Switzerland              30313     6795.590
# Spain                    26817    12621.500
# Japan                    25218      814.860
# Belgium                  23152     7540.130
# Norway                   19247     6529.060
# Portugal                 16153    13010.930
# Finland                  10666     3786.850
# Channel Islands           9473     3736.900
# Denmark                   8188     1266.950
# Italy                     7999     3879.390
# Cyprus                    6296     3880.040
# Singapore                 5234    25108.890
# Austria                   4827     1701.520
# ...

# %%
b = data_view.reset_index()
b
# Out:
#                  Country  Quantity    UnitPrice
# 0         United Kingdom   4250328  2233247.604
# 1            Netherlands    200128     6492.550
# 2                   EIRE    142495    48400.370
# 3                Germany    117341    37633.440
# 4                 France    110438    42985.980
# 5              Australia     83643     4048.000
# 6                 Sweden     35632     1804.730
# 7            Switzerland     30313     6795.590
# 8                  Spain     26817    12621.500
# 9                  Japan     25218      814.860
# 10               Belgium     23152     7540.130
# 11                Norway     19247     6529.060
# 12              Portugal     16153    13010.930
# 13               Finland     10666     3786.850
# 14       Channel Islands      9473     3736.900
# 15               Denmark      8188     1266.950
# 16                 Italy      7999     3879.390
# 17                Cyprus      6296     3880.040
# 18             Singapore      5234    25108.890
# ...

# %%
imp_col = country_group[["Country", "StockCode", "Description", "Quantity", "UnitPrice"]]
imp_col.groupby("Country", group_keys=True).apply(lambda x: x)
# Out:
#                Country StockCode                          Description  \
# 0       United Kingdom    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1       United Kingdom     71053                  WHITE METAL LANTERN
# 2       United Kingdom    84406B       CREAM CUPID HEARTS COAT HANGER
# 3       United Kingdom    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4       United Kingdom    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...                ...       ...                                  ...
# 541904          France     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905          France     22899         CHILDREN'S APRON DOLLY GIRL
# 541906          France     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907          France     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908          France     22138        BAKING SET 9 PIECE RETROSPOT
#
#         Quantity  UnitPrice
# 0              6       2.55
# 1              6       3.39
# 2              8       2.75
# ...

# %%
unique_country = imp_col.Country.value_counts()#[]
values_country = unique_country.reset_index()["index"].values
values_country
# Out:
# array(['United Kingdom', 'Germany', 'France', 'EIRE', 'Spain',
#        'Netherlands', 'Belgium', 'Switzerland', 'Portugal', 'Australia',
#        'Norway', 'Italy', 'Channel Islands', 'Finland', 'Cyprus',
#        'Sweden', 'Unspecified', 'Austria', 'Denmark', 'Japan', 'Poland',
#        'Israel', 'USA', 'Hong Kong', 'Singapore', 'Iceland', 'Canada',
#        'Greece', 'Malta', 'United Arab Emirates', 'European Community',
#        'RSA', 'Lebanon', 'Lithuania', 'Brazil', 'Czech Republic',
#        'Bahrain', 'Saudi Arabia'], dtype=object)

# %%
for nations in range(0,1):
    #print(nations)
    nat = imp_col[(imp_col.Country == values_country[nations])]
    sort_Quant = nat.sort_values(by="Quantity", ascending=False)
    #csv_output = sort_Quant.to_csv(values_country[nations], encoding='utf-8',  index=False)    #df.to_csv(file_name, sep='\t')
    #sort_price = nat.sort_values(by="UnitPrice", ascending=False)
sort_Quant
# Out:
#                Country StockCode                          Description  \
# 540421  United Kingdom     23843          PAPER CRAFT , LITTLE BIRDIE
# 61619   United Kingdom     23166       MEDIUM CERAMIC TOP STORAGE JAR
# 502122  United Kingdom     84826       ASSTD DESIGN 3D PAPER STICKERS
# 74614   United Kingdom     37413                                  NaN
# 421632  United Kingdom     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS
# ...                ...       ...                                  ...
# 4287    United Kingdom     84347  ROTATING SILVER ANGELS T-LIGHT HLDR
# 225530  United Kingdom     23005         printing smudges/thrown away
# 225529  United Kingdom     23005         printing smudges/thrown away
# 61624   United Kingdom     23166       MEDIUM CERAMIC TOP STORAGE JAR
# 540422  United Kingdom     23843          PAPER CRAFT , LITTLE BIRDIE
#
#         Quantity  UnitPrice
# 540421     80995       2.08
# 61619      74215       1.04
# 502122     12540       0.00
# ...

# %%
#imp_col[(imp_col.Country == "Germany")]

# %%
for nations in range(1,38):
    #print(nations)
    nat = imp_col[(imp_col.Country == values_country[nations])]
    sort_Quant = nat.sort_values(by="Quantity", ascending=False)
    csv_output = sort_Quant.to_csv("countries/"+values_country[nations], encoding='utf-8',  index=False)    #df.to_csv(file_name, sep='\t')
    #sort_price = nat.sort_values(by="UnitPrice", ascending=False)
#sort_Quant
csv_output

# %%
for nations in range(0,1):
    #print(nations)
    nat = imp_col[(imp_col.Country == values_country[nations])]
    sort_Quant = nat.sort_values(by="Quantity", ascending=False)
sort_Quant
# Out:
#                Country StockCode                          Description  \
# 540421  United Kingdom     23843          PAPER CRAFT , LITTLE BIRDIE
# 61619   United Kingdom     23166       MEDIUM CERAMIC TOP STORAGE JAR
# 502122  United Kingdom     84826       ASSTD DESIGN 3D PAPER STICKERS
# 74614   United Kingdom     37413                                  NaN
# 421632  United Kingdom     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS
# ...                ...       ...                                  ...
# 4287    United Kingdom     84347  ROTATING SILVER ANGELS T-LIGHT HLDR
# 225530  United Kingdom     23005         printing smudges/thrown away
# 225529  United Kingdom     23005         printing smudges/thrown away
# 61624   United Kingdom     23166       MEDIUM CERAMIC TOP STORAGE JAR
# 540422  United Kingdom     23843          PAPER CRAFT , LITTLE BIRDIE
#
#         Quantity  UnitPrice
# 540421     80995       2.08
# 61619      74215       1.04
# 502122     12540       0.00
# ...

# %%
value_count_stock = sort_Quant.StockCode.value_counts()
value_count_stock
# Out:
# 85123A    2204
# 85099B    1998
# 22423     1852
# 47566     1627
# 20725     1448
#           ...
# 85109        1
# 90187A       1
# 90152C       1
# 90214U       1
# 72140F       1
# Name: StockCode, Length: 4065, dtype: int64

# %%
value_count_stock = value_count_stock.reset_index()["index"].values
value_count_stock
# Out:
# array(['85123A', '85099B', 22423, ..., '90152C', '90214U', '72140F'],
#       dtype=object)

# %%
for key in range(0,100):
    sort_desc = sort_Quant[(sort_Quant["StockCode"] == value_count_stock[key])]
sort_desc
# Out:
#                Country StockCode                Description  Quantity  \
# 121854  United Kingdom     22385  JUMBO BAG SPACEBOY DESIGN       500
# 317544  United Kingdom     22385  JUMBO BAG SPACEBOY DESIGN       300
# 112056  United Kingdom     22385  JUMBO BAG SPACEBOY DESIGN       300
# 201359  United Kingdom     22385  JUMBO BAG SPACEBOY DESIGN       300
# 48858   United Kingdom     22385  JUMBO BAG SPACEBOY DESIGN       200
# ...                ...       ...                        ...       ...
# 280005  United Kingdom     22385  JUMBO BAG SPACEBOY DESIGN         1
# 329645  United Kingdom     22385  JUMBO BAG SPACEBOY DESIGN        -1
# 352799  United Kingdom     22385  JUMBO BAG SPACEBOY DESIGN        -7
# 146123  United Kingdom     22385  JUMBO BAG SPACEBOY DESIGN       -10
# 451773  United Kingdom     22385  JUMBO BAG SPACEBOY DESIGN      -100
#
#         UnitPrice
# 121854       1.65
# 317544       1.79
# 112056       1.65
# 201359       1.79
# 48858        1.65
# ...

# %%
desc_list = []
for key in range(0,100):
    sort_desc = sort_Quant[(sort_Quant["StockCode"] == value_count_stock[key])]
    desc = sort_desc.iloc[1][2]
    desc_list.append(desc)
desc_list
# Out:
# ['WHITE HANGING HEART T-LIGHT HOLDER',
#  'JUMBO BAG RED RETROSPOT',
#  'REGENCY CAKESTAND 3 TIER',
#  'PARTY BUNTING',
#  'LUNCH BAG RED RETROSPOT',
#  'ASSORTED COLOUR BIRD ORNAMENT',
#  'POPCORN HOLDER',
#  'SET OF 3 CAKE TINS PANTRY DESIGN ',
#  'LUNCH BAG  BLACK SKULL.',
#  'NATURAL SLATE HEART CHALKBOARD ',
#  'LUNCH BAG SUKI DESIGN ',
#  'HEART OF WICKER SMALL',
#  'JUMBO BAG PINK POLKADOT',
#  'PACK OF 72 RETROSPOT CAKE CASES',
#  'JUMBO BAG VINTAGE DOILY ',
#  'JUMBO STORAGE BAG SUKI',
#  "PAPER CHAIN KIT 50'S CHRISTMAS ",
#  'JUMBO SHOPPER VINTAGE RED PAISLEY',
#  'LUNCH BAG CARS BLUE',
#  'WOODEN PICTURE FRAME WHITE FINISH',
#  'RECIPE BOX PANTRY YELLOW DESIGN',
#  'SPOTTY BUNTING',
#  'JAM MAKING SET WITH JARS',
#  'LUNCH BAG SPACEBOY DESIGN ',
#  'LUNCH BAG PINK POLKADOT',
#  'VICTORIAN GLASS HANGING T-LIGHT',
#  'SET OF 4 PANTRY JELLY MOULDS',
#  'JAM MAKING SET PRINTED',
#  'LUNCH BAG DOILEY PATTERN ',
#  'ROSES REGENCY TEACUP AND SAUCER ',
# ...

# %%
sort_Quant[(sort_Quant["StockCode"] == value_count_stock[2])]
# Out:
#                Country StockCode               Description  Quantity  \
# 23263   United Kingdom     22423  REGENCY CAKESTAND 3 TIER       272
# 282261  United Kingdom     22423  REGENCY CAKESTAND 3 TIER       192
# 169823  United Kingdom     22423  REGENCY CAKESTAND 3 TIER       150
# 106784  United Kingdom     22423  REGENCY CAKESTAND 3 TIER       150
# 4505    United Kingdom     22423  REGENCY CAKESTAND 3 TIER       144
# ...                ...       ...                       ...       ...
# 52397   United Kingdom     22423  REGENCY CAKESTAND 3 TIER       -23
# 438487  United Kingdom     22423  REGENCY CAKESTAND 3 TIER       -24
# 441519  United Kingdom     22423  REGENCY CAKESTAND 3 TIER       -24
# 141938  United Kingdom     22423  REGENCY CAKESTAND 3 TIER       -48
# 309359  United Kingdom     22423  REGENCY CAKESTAND 3 TIER      -150
#
#         UnitPrice
# 23263       10.95
# 282261      10.95
# 169823      10.95
# 106784      10.95
# 4505        10.95
# ...           ...
# ...

# %%
sort_Quant[(sort_Quant["StockCode"] == value_count_stock[3])]
# Out:
#                Country StockCode    Description  Quantity  UnitPrice
# 253946  United Kingdom     47566  PARTY BUNTING       200       4.15
# 121916  United Kingdom     47566  PARTY BUNTING       150       4.15
# 204194  United Kingdom     47566  PARTY BUNTING       150       4.15
# 487878  United Kingdom     47566  PARTY BUNTING       150       4.15
# 291259  United Kingdom     47566  PARTY BUNTING       150       4.15
# ...                ...       ...            ...       ...        ...
# 378236  United Kingdom     47566  PARTY BUNTING       -11       4.95
# 385943  United Kingdom     47566  PARTY BUNTING       -20       3.74
# 383036  United Kingdom     47566  PARTY BUNTING       -29       4.15
# 367372  United Kingdom     47566  PARTY BUNTING       -50       4.15
# 171984  United Kingdom     47566  PARTY BUNTING      -100       4.15
#
# [1627 rows x 5 columns]

# %%
count_country = imp_col.Country.value_counts()
count_country
# Out:
# United Kingdom          490300
# Germany                   9480
# France                    8541
# EIRE                      8184
# Spain                     2528
# Netherlands               2371
# Belgium                   2069
# Switzerland               1994
# Portugal                  1510
# Australia                 1258
# Norway                    1086
# Italy                      803
# Channel Islands            757
# Finland                    695
# Cyprus                     611
# Sweden                     461
# Unspecified                442
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     294
# USA                        291
# Hong Kong                  284
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
imp_col.sort_values(by=["Quantity"], ascending=False)
# Out:
#                Country StockCode                          Description  \
# 540421  United Kingdom     23843          PAPER CRAFT , LITTLE BIRDIE
# 61619   United Kingdom     23166       MEDIUM CERAMIC TOP STORAGE JAR
# 502122  United Kingdom     84826       ASSTD DESIGN 3D PAPER STICKERS
# 74614   United Kingdom     37413                                  NaN
# 421632  United Kingdom     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS
# ...                ...       ...                                  ...
# 4287    United Kingdom     84347  ROTATING SILVER ANGELS T-LIGHT HLDR
# 225529  United Kingdom     23005         printing smudges/thrown away
# 225530  United Kingdom     23005         printing smudges/thrown away
# 61624   United Kingdom     23166       MEDIUM CERAMIC TOP STORAGE JAR
# 540422  United Kingdom     23843          PAPER CRAFT , LITTLE BIRDIE
#
#         Quantity  UnitPrice
# 540421     80995       2.08
# 61619      74215       1.04
# 502122     12540       0.00
# ...

# %%
imp_col.sort_values(by=["UnitPrice"], ascending=False)
# Out:
#                Country  StockCode                   Description  Quantity  \
# 222681  United Kingdom          M                        Manual        -1
# 524602  United Kingdom  AMAZONFEE                    AMAZON FEE        -1
# 43702   United Kingdom  AMAZONFEE                    AMAZON FEE        -1
# 43703   United Kingdom  AMAZONFEE                    AMAZON FEE        -1
# 15016   United Kingdom  AMAZONFEE                    AMAZON FEE        -1
# ...                ...        ...                           ...       ...
# 193208  United Kingdom      22520    CHILDS GARDEN TROWEL BLUE          1
# 193207  United Kingdom      22524  CHILDRENS GARDEN GLOVES BLUE         1
# 116919  United Kingdom     84029G                           NaN       280
# 299984  United Kingdom          B               Adjust bad debt         1
# 299983  United Kingdom          B               Adjust bad debt         1
#
#         UnitPrice
# 222681   38970.00
# 524602   17836.46
# 43702    16888.02
# ...

# %%
imp_col.groupby("StockCode", group_keys=True).apply(lambda x : x)
# Out:
#                Country StockCode                          Description  \
# 0       United Kingdom    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1       United Kingdom     71053                  WHITE METAL LANTERN
# 2       United Kingdom    84406B       CREAM CUPID HEARTS COAT HANGER
# 3       United Kingdom    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4       United Kingdom    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...                ...       ...                                  ...
# 541904          France     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905          France     22899         CHILDREN'S APRON DOLLY GIRL
# 541906          France     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907          France     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908          France     22138        BAKING SET 9 PIECE RETROSPOT
#
#         Quantity  UnitPrice
# 0              6       2.55
# 1              6       3.39
# 2              8       2.75
# ...

# %%
value_count_stock = imp_col.StockCode.value_counts()
value_count_stock
# Out:
# 85123A    2301
# 22423     2192
# 85099B    2156
# 47566     1720
# 20725     1626
#           ...
# 72781        1
# 35015        1
# 72793        1
# 72789        1
# 90091        1
# Name: StockCode, Length: 4070, dtype: int64

# %%
# !git pull origin master
# Out:
# From github.com:dekoma4u/Project
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !git add forage.pynb
# !git commit -m "Hide some files"
# !git push origin master
